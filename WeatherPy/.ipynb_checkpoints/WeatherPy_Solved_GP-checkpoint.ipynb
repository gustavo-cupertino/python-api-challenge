# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather_json = requests.get(query_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city = city_weather_json["name"] 
        city_lat = city_weather_json["coord"]["lat"]
        city_lng = city_weather_json["coord"]["lon"]
        city_max_temp = city_weather_json["main"]["temp_max"]
        city_humidity = city_weather_json["main"]["humidity"]
        city_clouds = city_weather_json["clouds"]["all"]
        city_wind = city_weather_json["wind"]["speed"]
        city_country = city_weather_json["sys"]["country"]
        city_date = city_weather_json["dt"]

        # Append the City information into city_data list
            
        city_data.append({"City": city,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
#Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | vestmannaeyjar
# Processing Record 6 of Set 1 | dargaville
# Processing Record 7 of Set 1 | pijao
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | general salgado
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | otradnoye
# Processing Record 20 of Set 1 | terrace
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | balkanabat
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | gigmoto
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | naze
# Processing Record 28 of Set 1 | havoysund
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | unirea
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | le port
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | scarborough
# Processing Record 38 of Set 1 | the valley
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | ewa beach
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 1 | gazalkent
# Processing Record 44 of Set 1 | balotra
# Processing Record 45 of Set 1 | fukue
# Processing Record 46 of Set 1 | north platte
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | luwuk
# Processing Record 49 of Set 1 | zyryanka
# Processing Record 50 of Set 1 | chiredzi
# Processing Record 0 of Set 2 | clyde river
# Processing Record 1 of Set 2 | savannah bight
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | umm lajj
# Processing Record 4 of Set 2 | katsuura
# Processing Record 5 of Set 2 | aksay
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | pochutla
# Processing Record 11 of Set 2 | outlook
# Processing Record 12 of Set 2 | banepa
# Processing Record 13 of Set 2 | asau
# Processing Record 14 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 2 | inhambane
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | pringsewu
# Processing Record 18 of Set 2 | opuwo
# Processing Record 19 of Set 2 | alexandria
# Processing Record 20 of Set 2 | bakchar
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | flin flon
# Processing Record 23 of Set 2 | zhangye
# Processing Record 24 of Set 2 | nouadhibou
# Processing Record 25 of Set 2 | ouadda
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | jahanabad
# Processing Record 29 of Set 2 | ocos
# Processing Record 30 of Set 2 | high prairie
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | derzhavinsk
# Processing Record 34 of Set 2 | hengyang
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | ilobu
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | tromso
# Processing Record 40 of Set 2 | acajutla
# Processing Record 41 of Set 2 | guane
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | doha
# Processing Record 44 of Set 2 | mount gambier
# Processing Record 45 of Set 2 | whitehorse
# Processing Record 46 of Set 2 | angoram
# Processing Record 47 of Set 2 | dankov
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | vao
# Processing Record 0 of Set 3 | longyearbyen
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | angoche
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | lazaro cardenas
# Processing Record 5 of Set 3 | luena
# Processing Record 6 of Set 3 | carauari
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | nushki
# Processing Record 10 of Set 3 | burgersdorp
# Processing Record 11 of Set 3 | asfi
# Processing Record 12 of Set 3 | progreso
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | beringovskiy
# Processing Record 15 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 16 of Set 3 | pacific grove
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | kirksville
# Processing Record 22 of Set 3 | skelleftea
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | zhezkazgan
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | jagraon
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | mahibadhoo
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | milkovo
# Processing Record 33 of Set 3 | oriximina
# Processing Record 34 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 3 | dongsheng
# Processing Record 36 of Set 3 | bonavista
# Processing Record 37 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | taksimo
# Processing Record 41 of Set 3 | tolaga bay
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | rabaul
# Processing Record 45 of Set 3 | tucumcari
# Processing Record 46 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 3 | kalabo
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | tres arroyos
# Processing Record 0 of Set 4 | marsh harbour
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | dombarovskiy
# Processing Record 3 of Set 4 | tirumullaivasal
# Processing Record 4 of Set 4 | starogard gdanski
# Processing Record 5 of Set 4 | comodoro rivadavia
# Processing Record 6 of Set 4 | lorengau
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | jodar
# Processing Record 9 of Set 4 | belaya gora
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | rundu
# Processing Record 14 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 4 | abu zabad
# Processing Record 16 of Set 4 | zarubino
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | puerto madryn
# Processing Record 19 of Set 4 | tura
# Processing Record 20 of Set 4 | yellowknife
# Processing Record 21 of Set 4 | matara
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | guaymas
# Processing Record 24 of Set 4 | lonar
# Processing Record 25 of Set 4 | chingirlau
# Processing Record 26 of Set 4 | baykit
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | komsomolskiy
# Processing Record 29 of Set 4 | nuevo casas grandes
# Processing Record 30 of Set 4 | el cobre
# Processing Record 31 of Set 4 | xinqing
# Processing Record 32 of Set 4 | saint-pierre
# Processing Record 33 of Set 4 | ketchikan
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | biysk
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | karacakoy
# Processing Record 41 of Set 4 | requena
# Processing Record 42 of Set 4 | cape town
# Processing Record 43 of Set 4 | saint albans
# Processing Record 44 of Set 4 | arenapolis
# Processing Record 45 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | gumushane
# City not found. Skipping...
# Processing Record 49 of Set 4 | bethel
# Processing Record 0 of Set 5 | gaspe
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | svetlogorsk
# Processing Record 3 of Set 5 | nagato
# Processing Record 4 of Set 5 | madisonville
# Processing Record 5 of Set 5 | gemena
# Processing Record 6 of Set 5 | kiama
# Processing Record 7 of Set 5 | ardakan
# Processing Record 8 of Set 5 | bardiyah
# Processing Record 9 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 5 | lensk
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | novikovo
# Processing Record 13 of Set 5 | pevek
# Processing Record 14 of Set 5 | portland
# Processing Record 15 of Set 5 | ossora
# Processing Record 16 of Set 5 | stephenville
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | vitim
# Processing Record 19 of Set 5 | chichihualco
# Processing Record 20 of Set 5 | idukki
# Processing Record 21 of Set 5 | osakarovka
# Processing Record 22 of Set 5 | monrovia
# Processing Record 23 of Set 5 | nantucket
# Processing Record 24 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 5 | champerico
# Processing Record 26 of Set 5 | huangmei
# Processing Record 27 of Set 5 | allada
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | sterling
# Processing Record 30 of Set 5 | huron
# Processing Record 31 of Set 5 | saint-philippe
# Processing Record 32 of Set 5 | oum hadjer
# Processing Record 33 of Set 5 | soe
# Processing Record 34 of Set 5 | uthai thani
# Processing Record 35 of Set 5 | cukai
# Processing Record 36 of Set 5 | puerto berrio
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | antofagasta
# Processing Record 39 of Set 5 | arrecife
# Processing Record 40 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | hofn
# Processing Record 42 of Set 5 | kampene
# Processing Record 43 of Set 5 | luis correia
# Processing Record 44 of Set 5 | mareeba
# Processing Record 45 of Set 5 | rio grande
# Processing Record 46 of Set 5 | yorkton
# Processing Record 47 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 0 of Set 6 | caohai
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | jalu
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | tulum
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | khakhea
# Processing Record 8 of Set 6 | liverpool
# Processing Record 9 of Set 6 | tual
# Processing Record 10 of Set 6 | ponta do sol
# Processing Record 11 of Set 6 | praia
# Processing Record 12 of Set 6 | imbituba
# Processing Record 13 of Set 6 | dingli
# Processing Record 14 of Set 6 | turukhansk
# Processing Record 15 of Set 6 | fomboni
# Processing Record 16 of Set 6 | carballo
# Processing Record 17 of Set 6 | puerto narino
# Processing Record 18 of Set 6 | sapao
# City not found. Skipping...
# Processing Record 19 of Set 6 | agarak
# Processing Record 20 of Set 6 | oranjemund
# Processing Record 21 of Set 6 | viedma
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | plettenberg bay
# Processing Record 25 of Set 6 | sechura
# Processing Record 26 of Set 6 | batticaloa
# Processing Record 27 of Set 6 | port hedland
# Processing Record 28 of Set 6 | taree
# Processing Record 29 of Set 6 | adrar
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | mackenzie
# Processing Record 32 of Set 6 | sangar
# Processing Record 33 of Set 6 | dulyapino
# Processing Record 34 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 35 of Set 6 | melilla
# Processing Record 36 of Set 6 | mar del plata
# Processing Record 37 of Set 6 | xichang
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | acari
# Processing Record 40 of Set 6 | panaba
# Processing Record 41 of Set 6 | khani
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | whithorn
# Processing Record 44 of Set 6 | pangkalanbuun
# Processing Record 45 of Set 6 | berberati
# Processing Record 46 of Set 6 | chokurdakh
# Processing Record 47 of Set 6 | narsaq
# Processing Record 48 of Set 6 | bubaque
# Processing Record 49 of Set 6 | ivanava
# Processing Record 0 of Set 7 | moussoro
# Processing Record 1 of Set 7 | ugoofaaru
# Processing Record 2 of Set 7 | nisia floresta
# Processing Record 3 of Set 7 | buala
# Processing Record 4 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 7 | soderhamn
# Processing Record 6 of Set 7 | barra da estiva
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | northam
# Processing Record 9 of Set 7 | vostok
# Processing Record 10 of Set 7 | presidencia roque saenz pena
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | lufilufi
# Processing Record 13 of Set 7 | santa maria
# Processing Record 14 of Set 7 | mabaruma
# Processing Record 15 of Set 7 | maceio
# Processing Record 16 of Set 7 | kavaratti
# Processing Record 17 of Set 7 | kitui
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 7 | poum
# Processing Record 21 of Set 7 | fort nelson
# Processing Record 22 of Set 7 | oksovskiy
# Processing Record 23 of Set 7 | mezhdurechensk
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | tecpan
# Processing Record 26 of Set 7 | eatonton
# Processing Record 27 of Set 7 | san jeronimo
# Processing Record 28 of Set 7 | leshukonskoye
# Processing Record 29 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 7 | verkhoturye
# Processing Record 31 of Set 7 | worcester
# Processing Record 32 of Set 7 | vila velha
# Processing Record 33 of Set 7 | riyadh
# Processing Record 34 of Set 7 | masyaf
# Processing Record 35 of Set 7 | mocajuba
# Processing Record 36 of Set 7 | soc trang
# Processing Record 37 of Set 7 | cabo san lucas
# Processing Record 38 of Set 7 | carutapera
# Processing Record 39 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 7 | kiboga
# Processing Record 41 of Set 7 | halmasd
# Processing Record 42 of Set 7 | denpasar
# Processing Record 43 of Set 7 | san rafael
# Processing Record 44 of Set 7 | machali
# Processing Record 45 of Set 7 | udachnyy
# Processing Record 46 of Set 7 | nova venecia
# Processing Record 47 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 48 of Set 7 | bartoszyce
# Processing Record 49 of Set 7 | huarmey
# Processing Record 0 of Set 8 | linhares
# Processing Record 1 of Set 8 | kirakira
# Processing Record 2 of Set 8 | necochea
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | port macquarie
# Processing Record 5 of Set 8 | sambava
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | rauma
# Processing Record 8 of Set 8 | sistranda
# Processing Record 9 of Set 8 | muravlenko
# Processing Record 10 of Set 8 | chapais
# Processing Record 11 of Set 8 | sobolevo
# Processing Record 12 of Set 8 | pokhara
# Processing Record 13 of Set 8 | la union
# Processing Record 14 of Set 8 | durango
# Processing Record 15 of Set 8 | mladenovac
# Processing Record 16 of Set 8 | bilma
# Processing Record 17 of Set 8 | aras
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | oktyabrskoye
# Processing Record 20 of Set 8 | san luis
# Processing Record 21 of Set 8 | aden
# Processing Record 22 of Set 8 | fort-shevchenko
# Processing Record 23 of Set 8 | fare
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | arlit
# Processing Record 26 of Set 8 | copiapo
# Processing Record 27 of Set 8 | giraltovce
# Processing Record 28 of Set 8 | borzya
# Processing Record 29 of Set 8 | batagay-alyta
# Processing Record 30 of Set 8 | yairipok
# Processing Record 31 of Set 8 | ambilobe
# Processing Record 32 of Set 8 | berdigestyakh
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | edgewater
# Processing Record 35 of Set 8 | petropavlovka
# Processing Record 36 of Set 8 | tumbagaan
# Processing Record 37 of Set 8 | abbeville
# Processing Record 38 of Set 8 | sosnovo-ozerskoye
# Processing Record 39 of Set 8 | ponta delgada
# Processing Record 40 of Set 8 | port lincoln
# Processing Record 41 of Set 8 | san juan
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | matam
# Processing Record 44 of Set 8 | ayorou
# Processing Record 45 of Set 8 | muros
# Processing Record 46 of Set 8 | mumford
# Processing Record 47 of Set 8 | cortez
# Processing Record 48 of Set 8 | waingapu
# Processing Record 49 of Set 8 | novobirilyussy
# Processing Record 0 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 9 | kahului
# Processing Record 2 of Set 9 | gore
# Processing Record 3 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 5 of Set 9 | kismayo
# Processing Record 6 of Set 9 | paka
# Processing Record 7 of Set 9 | saint-georges
# Processing Record 8 of Set 9 | vega de alatorre
# Processing Record 9 of Set 9 | marawi
# Processing Record 10 of Set 9 | harper
# Processing Record 11 of Set 9 | amalapuram
# Processing Record 12 of Set 9 | khawhai
# Processing Record 13 of Set 9 | anadyr
# Processing Record 14 of Set 9 | grindavik
# Processing Record 15 of Set 9 | mucurapo
# Processing Record 16 of Set 9 | pavelets
# Processing Record 17 of Set 9 | thinadhoo
# Processing Record 18 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 19 of Set 9 | tilichiki
# Processing Record 20 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | itzehoe
# Processing Record 23 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 9 | east millcreek
# Processing Record 25 of Set 9 | bagdarin
# Processing Record 26 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 9 | villa vazquez
# City not found. Skipping...
# Processing Record 28 of Set 9 | shelburne
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | barcelona
# Processing Record 31 of Set 9 | isangel
# Processing Record 32 of Set 9 | notre-dame-du-lac
# Processing Record 33 of Set 9 | alta floresta
# Processing Record 34 of Set 9 | saint george
# Processing Record 35 of Set 9 | bambous virieux
# Processing Record 36 of Set 9 | alofi
# Processing Record 37 of Set 9 | moose factory
# Processing Record 38 of Set 9 | guerrero negro
# Processing Record 39 of Set 9 | gat
# Processing Record 40 of Set 9 | krasnyy chikoy
# Processing Record 41 of Set 9 | neverkino
# Processing Record 42 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 43 of Set 9 | ipora
# Processing Record 44 of Set 9 | teya
# Processing Record 45 of Set 9 | palana
# Processing Record 46 of Set 9 | winneba
# Processing Record 47 of Set 9 | namatanai
# Processing Record 48 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 0 of Set 10 | dunedin
# Processing Record 1 of Set 10 | tel aviv-yafo
# Processing Record 2 of Set 10 | selikhino
# Processing Record 3 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 10 | blytheville
# Processing Record 5 of Set 10 | tabas
# Processing Record 6 of Set 10 | mormugao
# Processing Record 7 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 10 | lima
# Processing Record 9 of Set 10 | siraha
# Processing Record 10 of Set 10 | kushima
# Processing Record 11 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 10 | bilibino
# Processing Record 13 of Set 10 | thunder bay
# Processing Record 14 of Set 10 | kaeo
# Processing Record 15 of Set 10 | hobyo
# Processing Record 16 of Set 10 | addis zemen
# City not found. Skipping...
# Processing Record 17 of Set 10 | iquitos
# Processing Record 18 of Set 10 | caborca
# Processing Record 19 of Set 10 | yulara
# Processing Record 20 of Set 10 | angra
# City not found. Skipping...
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | meadow lake
# Processing Record 23 of Set 10 | kudahuvadhoo
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | lakes entrance
# Processing Record 26 of Set 10 | aasiaat
# Processing Record 27 of Set 10 | arequipa
# Processing Record 28 of Set 10 | la ronge
# Processing Record 29 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 10 | aykhal
# Processing Record 32 of Set 10 | mariestad
# Processing Record 33 of Set 10 | mongo
# Processing Record 34 of Set 10 | cururupu
# Processing Record 35 of Set 10 | lavrentiya
# Processing Record 36 of Set 10 | abu samrah
# Processing Record 37 of Set 10 | krasnovishersk
# Processing Record 38 of Set 10 | changji
# Processing Record 39 of Set 10 | birjand
# Processing Record 40 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 10 | mound
# Processing Record 42 of Set 10 | dongtai
# Processing Record 43 of Set 10 | cao bang
# Processing Record 44 of Set 10 | sao felix do xingu
# Processing Record 45 of Set 10 | te anau
# Processing Record 46 of Set 10 | verkhoyansk
# Processing Record 47 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 48 of Set 10 | cayenne
# Processing Record 49 of Set 10 | kamalpur
# Processing Record 0 of Set 11 | sarapul
# Processing Record 1 of Set 11 | natal
# Processing Record 2 of Set 11 | minden
# Processing Record 3 of Set 11 | saskylakh
# Processing Record 4 of Set 11 | gari
# Processing Record 5 of Set 11 | codrington
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | mayo
# Processing Record 8 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 11 | palauig
# Processing Record 10 of Set 11 | lodja
# Processing Record 11 of Set 11 | yerbogachen
# Processing Record 12 of Set 11 | shenjiamen
# Processing Record 13 of Set 11 | kulhudhuffushi
# Processing Record 14 of Set 11 | kaitong
# Processing Record 15 of Set 11 | ballina
# Processing Record 16 of Set 11 | biscarrosse
# Processing Record 17 of Set 11 | itarema
# Processing Record 18 of Set 11 | barreirinhas
# Processing Record 19 of Set 11 | lekoni
# Processing Record 20 of Set 11 | severnyy
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | selizharovo
# Processing Record 23 of Set 11 | qasigiannguit
# Processing Record 24 of Set 11 | mayumba
# Processing Record 25 of Set 11 | yei
# Processing Record 26 of Set 11 | yar-sale
# Processing Record 27 of Set 11 | hudiksvall
# Processing Record 28 of Set 11 | nicoya
# Processing Record 29 of Set 11 | papetoai
# Processing Record 30 of Set 11 | sola
# Processing Record 31 of Set 11 | puerto quijarro
# Processing Record 32 of Set 11 | crotone
# Processing Record 33 of Set 11 | san cristobal
# Processing Record 34 of Set 11 | jiwani
# Processing Record 35 of Set 11 | sarakhs
# Processing Record 36 of Set 11 | tiznit
# Processing Record 37 of Set 11 | katha
# City not found. Skipping...
# Processing Record 38 of Set 11 | gilgil
# City not found. Skipping...
# Processing Record 39 of Set 11 | mukhen
# Processing Record 40 of Set 11 | treinta y tres
# Processing Record 41 of Set 11 | tazovskiy
# Processing Record 42 of Set 11 | kawanoe
# Processing Record 43 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 11 | nyurba
# Processing Record 45 of Set 11 | pemangkat
# Processing Record 46 of Set 11 | santa catarina de tepehuanes
# Processing Record 47 of Set 11 | bandarbeyla
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | san policarpo
# Processing Record 0 of Set 12 | tuatapere
# Processing Record 1 of Set 12 | thurso
# Processing Record 2 of Set 12 | cariamanga
# Processing Record 3 of Set 12 | port hardy
# Processing Record 4 of Set 12 | wad madani
# Processing Record 5 of Set 12 | grants
# Processing Record 6 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 12 | moji das cruzes
# City not found. Skipping...
# Processing Record 8 of Set 12 | guanica
# Processing Record 9 of Set 12 | synya
# Processing Record 10 of Set 12 | george
# Processing Record 11 of Set 12 | wazzan
# City not found. Skipping...
# Processing Record 12 of Set 12 | igrim
# Processing Record 13 of Set 12 | klaksvik
# Processing Record 14 of Set 12 | solnechnyy
# Processing Record 15 of Set 12 | borgarnes
# Processing Record 16 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 12 | chimoio
# Processing Record 18 of Set 12 | lompoc
# Processing Record 19 of Set 12 | kidal
# Processing Record 20 of Set 12 | san miguel
# Processing Record 21 of Set 12 | dubrovytsya
# Processing Record 22 of Set 12 | miguel pereira
# Processing Record 23 of Set 12 | mao
# Processing Record 24 of Set 12 | road town
# Processing Record 25 of Set 12 | shellbrook
# Processing Record 26 of Set 12 | prykolotne
# Processing Record 27 of Set 12 | guiyang
# Processing Record 28 of Set 12 | visby
# Processing Record 29 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 12 | wuwei
# Processing Record 31 of Set 12 | taitung
# Processing Record 32 of Set 12 | ahipara
# Processing Record 33 of Set 12 | takoradi
# Processing Record 34 of Set 12 | medea
# Processing Record 35 of Set 12 | wakkanai
# Processing Record 36 of Set 12 | san ramon
# Processing Record 37 of Set 12 | minas de barroteran
# Processing Record 38 of Set 12 | port blair
# Processing Record 39 of Set 12 | nome
# Processing Record 40 of Set 12 | port moresby
# Processing Record 41 of Set 12 | saint-augustin
# Processing Record 42 of Set 12 | sorland
# Processing Record 43 of Set 12 | bintulu
# Processing Record 44 of Set 12 | sakakah
# Processing Record 45 of Set 12 | dinan
# Processing Record 46 of Set 12 | agustin codazzi
# Processing Record 47 of Set 12 | miri
# Processing Record 48 of Set 12 | tieling
# Processing Record 49 of Set 12 | kjollefjord
# Processing Record 0 of Set 13 | saint anthony
# Processing Record 1 of Set 13 | madison
# Processing Record 2 of Set 13 | kaitangata
# Processing Record 3 of Set 13 | sawakin
# Processing Record 4 of Set 13 | canto do buriti
# Processing Record 5 of Set 13 | smoky lake
# Processing Record 6 of Set 13 | aitape
# Processing Record 7 of Set 13 | marsa matruh
# Processing Record 8 of Set 13 | sinnamary
# Processing Record 9 of Set 13 | ustye
# Processing Record 10 of Set 13 | serik
# Processing Record 11 of Set 13 | kenai
# Processing Record 12 of Set 13 | kapiri mposhi
# Processing Record 13 of Set 13 | tupik
# Processing Record 14 of Set 13 | berlevag
# Processing Record 15 of Set 13 | pilar
# Processing Record 16 of Set 13 | goundi
# Processing Record 17 of Set 13 | saldanha
# Processing Record 18 of Set 13 | okhotsk
# Processing Record 19 of Set 13 | santa cruz
# Processing Record 20 of Set 13 | brigantine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lagoa  39.0500  -27.9833     13.26        71          96
# 1       Busselton -33.6500  115.3333     19.36        78          84
# 2     Port Alfred -33.5906   26.8910     22.32        90          95
# 3  Vestmannaeyjar  63.4427  -20.2734      1.55        86          75
# 4      Dargaville -35.9333  173.8833     17.71        83          61
#
#    Wind Speed Country        Date
# 0       12.60      PT  1675709103
# 1        5.40      AU  1675709103
# 2        1.79      ZA  1675709104
# 3       17.49      IS  1675709060
# 4        1.95      NZ  1675709106

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 Lagoa  39.0500  -27.9833     13.26        71          96
# 1             Busselton -33.6500  115.3333     19.36        78          84
# 2           Port Alfred -33.5906   26.8910     22.32        90          95
# 3        Vestmannaeyjar  63.4427  -20.2734      1.55        86          75
# 4            Dargaville -35.9333  173.8833     17.71        83          61
#
#          Wind Speed Country        Date
# City_ID
# 0             12.60      PT  1675709103
# 1              5.40      AU  1675709103
# 2              1.79      ZA  1675709104
# 3             17.49      IS  1675709060
# 4              1.95      NZ  1675709106

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
plt.title("City Latitude vs Max Temperature (Date here)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# timestamp = city_data_df["Date"][0]
# timestamp

# dt_obj = time.strftime("%Y %m %d", timestamp)

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.title("City Latitude vs Humidity (Date here)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.title("City Latitude vs Cloudiness (Date here)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
plt.title("City Latitude vs Wind Speed (Date here)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression(x_values, y_values):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(0.1, 0.9), xycoords='axes fraction', fontsize=15,color="red")
#     plt.xlabel ("Latitude")
#     plt.ylabel ("xxxx")
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0),:]

# Display sample data

northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 Lagoa  39.0500  -27.9833     13.26        71          96
# 3        Vestmannaeyjar  63.4427  -20.2734      1.55        86          75
# 5                 Pijao   4.3342  -75.7035     23.55        61          75
# 6                Albany  42.6001  -73.9662      4.65        75          92
# 10          Tuktoyaktuk  69.4541 -133.0374    -42.00        66          20
#
#          Wind Speed Country        Date
# City_ID
# 0             12.60      PT  1675709103
# 3             17.49      IS  1675709060
# 5              0.00      CO  1675709106
# 6              0.45      US  1675709027
# 10             1.03      CA  1675709107

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0),:]

# Display sample data

southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          Busselton -33.6500  115.3333     19.36        78          84
# 2        Port Alfred -33.5906   26.8910     22.32        90          95
# 4         Dargaville -35.9333  173.8833     17.71        83          61
# 7            Rikitea -23.1203 -134.9692     25.80        74           7
# 8           Coquimbo -29.9533  -71.3436     20.85        73          75
#
#          Wind Speed Country        Date
# City_ID
# 1              5.40      AU  1675709103
# 2              1.79      ZA  1675709104
# 4              1.95      NZ  1675709106
# 7              3.04      PF  1675708976
# 8              5.14      CL  1675708958

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plt.xlabel ("Latitude")
plt.ylabel ("Max Temp")

linear_regression(x_values, y_values)
# Out:
# The r-squared is: 0.7437005937032788

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plt.xlabel ("Latitude")
plt.ylabel ("Max Temp")

linear_regression(x_values, y_values)
# Out:
# The r-squared is: 0.17627960964074818

# %% [markdown]
# **Discussion about the linear relationship:**
#
# When analysing the relationship between latitude and max tempuratures for cities on the Northern Hemisphere, there is a strong negative correlation (r = 0.74): max temperature drops as the latitude increases.
#
# On the other hand, there is a very week positive correlation between the same two variables on the Southern Hemisphere (r = 0.17).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plt.xlabel ("Latitude")
plt.ylabel ("Humidity")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 0.24830131292723878

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plt.xlabel ("Latitude")
plt.ylabel ("Humidity")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 0.06823810773503437

# %% [markdown]
# **Discussion about the linear relationship:**
#
# When analysing the relationship between latitude and humidity for cities on the Northern Hemisphere, it is possible to notice a very week positive correlation (r = 0.24), while there is no correlation at all (r = 0.06) between the same variables for cities located on Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plt.xlabel ("Latitude")
plt.ylabel ("Cloudiness")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 0.08181925409523785

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plt.xlabel ("Latitude")
plt.ylabel ("Cloudiness")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 0.15005466251098892

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no correlation between Latitude and Cloudiness for cities on both hemispheres (r < 0.3).

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plt.xlabel ("Latitude")
plt.ylabel ("Wind Speed")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 3.212897320804087e-06

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plt.xlabel ("Latitude")
plt.ylabel ("Wind Speed")

liner_regression(x_values, y_values)
# Out:
# The r-squared is: 0.08425621464075053

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no correlation between Latitude and Wind Speed for cities on both hemispheres (r < 0.3).
