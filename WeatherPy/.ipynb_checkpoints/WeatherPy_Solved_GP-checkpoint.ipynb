# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import datetime as dt
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather_json = requests.get(query_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city = city_weather_json["name"] 
        city_lat = city_weather_json["coord"]["lat"]
        city_lng = city_weather_json["coord"]["lon"]
        city_max_temp = city_weather_json["main"]["temp_max"]
        city_humidity = city_weather_json["main"]["humidity"]
        city_clouds = city_weather_json["clouds"]["all"]
        city_wind = city_weather_json["wind"]["speed"]
        city_country = city_weather_json["sys"]["country"]
        city_date = city_weather_json["dt"]

        # Append the City information into city_data list
            
        city_data.append({"City": city,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
#Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | stralsund
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | henties bay
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | ballyshannon
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | marovoay
# Processing Record 12 of Set 1 | saint-joseph
# Processing Record 13 of Set 1 | verkhoyansk
# Processing Record 14 of Set 1 | vardo
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | lata
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | kingsville
# Processing Record 20 of Set 1 | datong
# Processing Record 21 of Set 1 | deep river
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | omboue
# Processing Record 24 of Set 1 | adrar
# Processing Record 25 of Set 1 | nizhniy kuranakh
# Processing Record 26 of Set 1 | orlik
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | port blair
# Processing Record 29 of Set 1 | takoradi
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | skegness
# Processing Record 33 of Set 1 | oktyabrskiy
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | novopodrezkovo
# Processing Record 37 of Set 1 | svetlaya
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | rocky mountain house
# Processing Record 40 of Set 1 | wamba
# Processing Record 41 of Set 1 | saint anthony
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | puga
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | amberley
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | asyut
# Processing Record 0 of Set 2 | talnakh
# Processing Record 1 of Set 2 | alanya
# Processing Record 2 of Set 2 | calabozo
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | carballo
# Processing Record 6 of Set 2 | pirogovo
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | dillon
# Processing Record 10 of Set 2 | matay
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | kargasok
# Processing Record 14 of Set 2 | vostok
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | lehola
# Processing Record 20 of Set 2 | kavaratti
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | tortoli
# Processing Record 23 of Set 2 | itoman
# Processing Record 24 of Set 2 | borogontsy
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | neiafu
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | sangar
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | uberlandia
# Processing Record 36 of Set 2 | srednekolymsk
# Processing Record 37 of Set 2 | aripuana
# Processing Record 38 of Set 2 | anadyr
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | ostersund
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | diego de almagro
# Processing Record 43 of Set 2 | zalantun
# Processing Record 44 of Set 2 | alegrete
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | saint albans
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | yulara
# Processing Record 0 of Set 3 | tema
# Processing Record 1 of Set 3 | lufilufi
# Processing Record 2 of Set 3 | kyra
# Processing Record 3 of Set 3 | saint-francois
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | severo-yeniseyskiy
# Processing Record 6 of Set 3 | kidal
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | hobyo
# Processing Record 11 of Set 3 | alofi
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | we
# City not found. Skipping...
# Processing Record 14 of Set 3 | chihuahua
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | erzin
# Processing Record 18 of Set 3 | usinsk
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | maridi
# Processing Record 21 of Set 3 | ambulu
# Processing Record 22 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | beyneu
# Processing Record 28 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 3 | matane
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | la sarre
# Processing Record 33 of Set 3 | hay river
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | san miguel
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | cherskiy
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | lianzhou
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | samana
# Processing Record 47 of Set 3 | srandakan
# Processing Record 48 of Set 3 | aykhal
# Processing Record 49 of Set 3 | christiana
# Processing Record 0 of Set 4 | ponta do sol
# Processing Record 1 of Set 4 | coxim
# Processing Record 2 of Set 4 | powell river
# Processing Record 3 of Set 4 | bethel
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | anshun
# Processing Record 8 of Set 4 | lompoc
# Processing Record 9 of Set 4 | wanning
# Processing Record 10 of Set 4 | strezhevoy
# Processing Record 11 of Set 4 | posyet
# Processing Record 12 of Set 4 | kapit
# Processing Record 13 of Set 4 | boone
# Processing Record 14 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | volta redonda
# Processing Record 17 of Set 4 | bagdarin
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | cairns
# Processing Record 20 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 4 | darnah
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | kaseda
# Processing Record 24 of Set 4 | batagay-alyta
# Processing Record 25 of Set 4 | galveston
# Processing Record 26 of Set 4 | barranca
# Processing Record 27 of Set 4 | pamanukan
# Processing Record 28 of Set 4 | san policarpo
# Processing Record 29 of Set 4 | cheremukhovo
# Processing Record 30 of Set 4 | ostrovnoy
# Processing Record 31 of Set 4 | chuy
# Processing Record 32 of Set 4 | verkhoshizhemye
# Processing Record 33 of Set 4 | sharlyk
# Processing Record 34 of Set 4 | kismayo
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | terrace
# Processing Record 38 of Set 4 | basar
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | roald
# Processing Record 42 of Set 4 | saint-georges
# Processing Record 43 of Set 4 | kodinsk
# Processing Record 44 of Set 4 | kibala
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | morros
# Processing Record 48 of Set 4 | brae
# Processing Record 49 of Set 4 | codrington
# Processing Record 0 of Set 5 | oussouye
# Processing Record 1 of Set 5 | pacifica
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | nyagan
# Processing Record 5 of Set 5 | cidreira
# Processing Record 6 of Set 5 | beisfjord
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | ixhuatan
# Processing Record 9 of Set 5 | salinopolis
# Processing Record 10 of Set 5 | burica
# City not found. Skipping...
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | noumea
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | fare
# Processing Record 16 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 5 | ipora
# Processing Record 18 of Set 5 | benguela
# Processing Record 19 of Set 5 | bhag
# Processing Record 20 of Set 5 | marawi
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | youghal
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | castro
# Processing Record 25 of Set 5 | tarbagatay
# Processing Record 26 of Set 5 | kamariotissa
# Processing Record 27 of Set 5 | sergeyevka
# Processing Record 28 of Set 5 | tornio
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | spodnje hoce
# Processing Record 31 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 5 | concordia
# Processing Record 33 of Set 5 | qaanaaq
# Processing Record 34 of Set 5 | havre-saint-pierre
# Processing Record 35 of Set 5 | kahului
# Processing Record 36 of Set 5 | santo antonio do ica
# Processing Record 37 of Set 5 | assai
# Processing Record 38 of Set 5 | necochea
# Processing Record 39 of Set 5 | villeneuve-sur-lot
# Processing Record 40 of Set 5 | port-de-bouc
# Processing Record 41 of Set 5 | sorland
# Processing Record 42 of Set 5 | port lincoln
# Processing Record 43 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 5 | port hardy
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | nador
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | mamlyutka
# Processing Record 49 of Set 5 | verkhnyaya inta
# Processing Record 0 of Set 6 | zyryanka
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | tara
# Processing Record 3 of Set 6 | vao
# Processing Record 4 of Set 6 | mujiayingzi
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | sokoni
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 6 | key west
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 12 of Set 6 | caetite
# Processing Record 13 of Set 6 | sola
# Processing Record 14 of Set 6 | lakes entrance
# Processing Record 15 of Set 6 | beba
# Processing Record 16 of Set 6 | balikpapan
# Processing Record 17 of Set 6 | nabire
# Processing Record 18 of Set 6 | caraballeda
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | borisoglebsk
# Processing Record 21 of Set 6 | okhotsk
# Processing Record 22 of Set 6 | hudson bay
# Processing Record 23 of Set 6 | dubinino
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | huarmey
# Processing Record 26 of Set 6 | benghazi
# Processing Record 27 of Set 6 | taltal
# Processing Record 28 of Set 6 | yurginskoye
# Processing Record 29 of Set 6 | newport
# Processing Record 30 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 6 | yellowknife
# Processing Record 32 of Set 6 | bani walid
# Processing Record 33 of Set 6 | tuy hoa
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | sorong
# Processing Record 36 of Set 6 | dali
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | mount gambier
# Processing Record 39 of Set 6 | jiwani
# Processing Record 40 of Set 6 | tezu
# Processing Record 41 of Set 6 | cam ranh
# Processing Record 42 of Set 6 | ormara
# Processing Record 43 of Set 6 | sobolevo
# Processing Record 44 of Set 6 | college
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | egvekinot
# Processing Record 47 of Set 6 | arawa
# Processing Record 48 of Set 6 | churapcha
# Processing Record 49 of Set 6 | vestmanna
# Processing Record 0 of Set 7 | zhaocheng
# City not found. Skipping...
# Processing Record 1 of Set 7 | save
# Processing Record 2 of Set 7 | ranot
# Processing Record 3 of Set 7 | thinadhoo
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | piacabucu
# Processing Record 6 of Set 7 | lindsay
# Processing Record 7 of Set 7 | cabedelo
# Processing Record 8 of Set 7 | padang
# Processing Record 9 of Set 7 | saldanha
# Processing Record 10 of Set 7 | ayan
# Processing Record 11 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 7 | san rafael
# Processing Record 13 of Set 7 | port-gentil
# Processing Record 14 of Set 7 | hambantota
# Processing Record 15 of Set 7 | sibolga
# Processing Record 16 of Set 7 | auki
# Processing Record 17 of Set 7 | muyezerskiy
# Processing Record 18 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | dehloran
# Processing Record 21 of Set 7 | beya
# Processing Record 22 of Set 7 | sabang
# Processing Record 23 of Set 7 | chiredzi
# Processing Record 24 of Set 7 | maniitsoq
# Processing Record 25 of Set 7 | dalbandin
# Processing Record 26 of Set 7 | kenitra
# Processing Record 27 of Set 7 | manitouwadge
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | qandala
# Processing Record 30 of Set 7 | pio ix
# Processing Record 31 of Set 7 | manokwari
# Processing Record 32 of Set 7 | sisimiut
# Processing Record 33 of Set 7 | hofn
# Processing Record 34 of Set 7 | la palma
# Processing Record 35 of Set 7 | domoni
# Processing Record 36 of Set 7 | solnechnyy
# Processing Record 37 of Set 7 | balatonfenyves
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | tokur
# Processing Record 40 of Set 7 | la ronge
# Processing Record 41 of Set 7 | tarrafal
# Processing Record 42 of Set 7 | denia
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | patur
# Processing Record 45 of Set 7 | abu kamal
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | beira
# Processing Record 48 of Set 7 | avera
# Processing Record 49 of Set 7 | sept-iles
# Processing Record 0 of Set 8 | nuristan
# Processing Record 1 of Set 8 | nichinan
# Processing Record 2 of Set 8 | abha
# Processing Record 3 of Set 8 | nanortalik
# Processing Record 4 of Set 8 | farafangana
# Processing Record 5 of Set 8 | tuatapere
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | amur
# Processing Record 8 of Set 8 | tura
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | kaitangata
# Processing Record 12 of Set 8 | cumberland
# Processing Record 13 of Set 8 | raia
# Processing Record 14 of Set 8 | deputatskiy
# Processing Record 15 of Set 8 | ordzhonikidze
# Processing Record 16 of Set 8 | dryden
# Processing Record 17 of Set 8 | cosolapa
# Processing Record 18 of Set 8 | winsum
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | burnie
# Processing Record 21 of Set 8 | north bend
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | divo
# Processing Record 25 of Set 8 | westport
# Processing Record 26 of Set 8 | nioro
# Processing Record 27 of Set 8 | zhaotong
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | teeli
# Processing Record 30 of Set 8 | mbekenyera
# Processing Record 31 of Set 8 | tarnobrzeg
# Processing Record 32 of Set 8 | mabaruma
# Processing Record 33 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 8 | hervey bay
# Processing Record 35 of Set 8 | talaya
# Processing Record 36 of Set 8 | georgetown
# Processing Record 37 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 8 | gushikawa
# Processing Record 39 of Set 8 | prince rupert
# Processing Record 40 of Set 8 | mayumba
# Processing Record 41 of Set 8 | villamontes
# Processing Record 42 of Set 8 | cayenne
# Processing Record 43 of Set 8 | palembang
# Processing Record 44 of Set 8 | taoudenni
# Processing Record 45 of Set 8 | brigantine
# Processing Record 46 of Set 8 | matara
# Processing Record 47 of Set 8 | burgess hill
# Processing Record 48 of Set 8 | huron
# Processing Record 49 of Set 8 | kaniama
# Processing Record 0 of Set 9 | teya
# Processing Record 1 of Set 9 | zhicheng
# Processing Record 2 of Set 9 | katobu
# Processing Record 3 of Set 9 | numaran
# Processing Record 4 of Set 9 | charters towers
# Processing Record 5 of Set 9 | amot
# Processing Record 6 of Set 9 | pocoes
# Processing Record 7 of Set 9 | vysha
# Processing Record 8 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 9 | petrove
# Processing Record 10 of Set 9 | hamilton
# Processing Record 11 of Set 9 | bowen
# Processing Record 12 of Set 9 | soma
# Processing Record 13 of Set 9 | ushtobe
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | kupang
# Processing Record 16 of Set 9 | flagstaff
# Processing Record 17 of Set 9 | rawson
# Processing Record 18 of Set 9 | kaeo
# Processing Record 19 of Set 9 | porangatu
# Processing Record 20 of Set 9 | trinidad
# Processing Record 21 of Set 9 | pringsewu
# Processing Record 22 of Set 9 | buala
# Processing Record 23 of Set 9 | jalu
# Processing Record 24 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 9 | namatanai
# Processing Record 26 of Set 9 | mercedes
# Processing Record 27 of Set 9 | honningsvag
# Processing Record 28 of Set 9 | sinnamary
# Processing Record 29 of Set 9 | walvis bay
# Processing Record 30 of Set 9 | katsuura
# Processing Record 31 of Set 9 | soldato-aleksandrovskoye
# Processing Record 32 of Set 9 | isangel
# Processing Record 33 of Set 9 | brookhaven
# Processing Record 34 of Set 9 | chokwe
# Processing Record 35 of Set 9 | sitka
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | burriana
# Processing Record 38 of Set 9 | ancud
# Processing Record 39 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 9 | martapura
# Processing Record 41 of Set 9 | san carlos de bariloche
# Processing Record 42 of Set 9 | new waterford
# Processing Record 43 of Set 9 | richards bay
# Processing Record 44 of Set 9 | palmer
# Processing Record 45 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | bolshaya murta
# City not found. Skipping...
# Processing Record 47 of Set 9 | trail
# Processing Record 48 of Set 9 | sambava
# Processing Record 49 of Set 9 | ati
# Processing Record 0 of Set 10 | xining
# Processing Record 1 of Set 10 | kharp
# Processing Record 2 of Set 10 | iracoubo
# Processing Record 3 of Set 10 | soddy-daisy
# Processing Record 4 of Set 10 | hemsedal
# Processing Record 5 of Set 10 | ahuimanu
# Processing Record 6 of Set 10 | synya
# Processing Record 7 of Set 10 | kontagora
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | crixas
# Processing Record 10 of Set 10 | mbumi
# Processing Record 11 of Set 10 | amahai
# Processing Record 12 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 10 | ahipara
# Processing Record 14 of Set 10 | langsa
# Processing Record 15 of Set 10 | bambanglipuro
# Processing Record 16 of Set 10 | dingle
# Processing Record 17 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 10 | bozdar
# Processing Record 19 of Set 10 | medea
# Processing Record 20 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 10 | havoysund
# Processing Record 22 of Set 10 | belyy yar
# Processing Record 23 of Set 10 | latung
# Processing Record 24 of Set 10 | buchanan
# Processing Record 25 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 10 | chapada dos guimaraes
# Processing Record 27 of Set 10 | kondinskoye
# Processing Record 28 of Set 10 | bahia honda
# Processing Record 29 of Set 10 | berlevag
# Processing Record 30 of Set 10 | ocos
# Processing Record 31 of Set 10 | verkhniye kigi
# Processing Record 32 of Set 10 | husavik
# Processing Record 33 of Set 10 | kanniyakumari
# Processing Record 34 of Set 10 | la mira
# Processing Record 35 of Set 10 | kikwit
# Processing Record 36 of Set 10 | shimanovsk
# Processing Record 37 of Set 10 | cap malheureux
# Processing Record 38 of Set 10 | tucumcari
# Processing Record 39 of Set 10 | chaumont
# Processing Record 40 of Set 10 | gaillac
# Processing Record 41 of Set 10 | phalombe
# Processing Record 42 of Set 10 | kedrovyy
# Processing Record 43 of Set 10 | margate
# Processing Record 44 of Set 10 | soyo
# Processing Record 45 of Set 10 | ukiah
# Processing Record 46 of Set 10 | chase
# Processing Record 47 of Set 10 | trelleborg
# Processing Record 48 of Set 10 | togur
# Processing Record 49 of Set 10 | arlit
# Processing Record 0 of Set 11 | staszow
# Processing Record 1 of Set 11 | mirabad
# Processing Record 2 of Set 11 | pakpattan
# Processing Record 3 of Set 11 | tiksi
# Processing Record 4 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 11 | consuegra
# Processing Record 6 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 11 | goderich
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | dudinka
# Processing Record 11 of Set 11 | pocao de pedras
# Processing Record 12 of Set 11 | ullapool
# Processing Record 13 of Set 11 | lucapa
# Processing Record 14 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 15 of Set 11 | buritis
# Processing Record 16 of Set 11 | kuliyapitiya
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | buraydah
# Processing Record 19 of Set 11 | craig
# Processing Record 20 of Set 11 | sawakin
# Processing Record 21 of Set 11 | shimoda
# Processing Record 22 of Set 11 | coruripe
# Processing Record 23 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 11 | latehar
# Processing Record 25 of Set 11 | porto novo
# Processing Record 26 of Set 11 | curuguaty
# Processing Record 27 of Set 11 | conceicao do araguaia
# Processing Record 28 of Set 11 | killarney
# Processing Record 29 of Set 11 | tautira
# Processing Record 30 of Set 11 | zlotow
# Processing Record 31 of Set 11 | methoni
# Processing Record 32 of Set 11 | blairmore
# Processing Record 33 of Set 11 | lucea
# Processing Record 34 of Set 11 | kirakira
# Processing Record 35 of Set 11 | bhawana
# Processing Record 36 of Set 11 | nishihara
# Processing Record 37 of Set 11 | kostomuksha
# Processing Record 38 of Set 11 | kabarnet
# Processing Record 39 of Set 11 | flinders
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | kushima
# Processing Record 42 of Set 11 | etchoropo
# Processing Record 43 of Set 11 | waingapu
# Processing Record 44 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 11 | sur
# Processing Record 46 of Set 11 | chitral
# Processing Record 47 of Set 11 | mehamn
# Processing Record 48 of Set 11 | champerico
# Processing Record 49 of Set 11 | hualmay
# Processing Record 0 of Set 12 | ledyard
# Processing Record 1 of Set 12 | marau
# Processing Record 2 of Set 12 | saint george
# Processing Record 3 of Set 12 | najran
# Processing Record 4 of Set 12 | coquimbo
# Processing Record 5 of Set 12 | kutoarjo
# Processing Record 6 of Set 12 | port keats
# Processing Record 7 of Set 12 | san cristobal
# Processing Record 8 of Set 12 | tarnogskiy gorodok
# Processing Record 9 of Set 12 | daru
# Processing Record 10 of Set 12 | bahir dar
# Processing Record 11 of Set 12 | ixtapa
# Processing Record 12 of Set 12 | tongchuan
# Processing Record 13 of Set 12 | yei
# Processing Record 14 of Set 12 | varkkallai
# Processing Record 15 of Set 12 | mackay
# Processing Record 16 of Set 12 | dunedin
# Processing Record 17 of Set 12 | pangnirtung
# Processing Record 18 of Set 12 | mukhen
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | alexandria
# Processing Record 21 of Set 12 | los llanos de aridane
# Processing Record 22 of Set 12 | banda aceh
# Processing Record 23 of Set 12 | merke
# Processing Record 24 of Set 12 | lensk
# Processing Record 25 of Set 12 | casimiro de abreu
# Processing Record 26 of Set 12 | gigmoto
# Processing Record 27 of Set 12 | deloraine
# Processing Record 28 of Set 12 | leh
# Processing Record 29 of Set 12 | pisco
# Processing Record 30 of Set 12 | prince george
# Processing Record 31 of Set 12 | yar-sale
# Processing Record 32 of Set 12 | meulaboh
# Processing Record 33 of Set 12 | ajdabiya
# Processing Record 34 of Set 12 | scarborough
# Processing Record 35 of Set 12 | samarai
# Processing Record 36 of Set 12 | guozhen
# Processing Record 37 of Set 12 | paraguacu paulista
# Processing Record 38 of Set 12 | kardzhin
# Processing Record 39 of Set 12 | rivera
# Processing Record 40 of Set 12 | shahreza
# Processing Record 41 of Set 12 | mao
# Processing Record 42 of Set 12 | tenkodogo
# Processing Record 43 of Set 12 | ca mau
# Processing Record 44 of Set 12 | nemuro
# Processing Record 45 of Set 12 | taganak
# Processing Record 46 of Set 12 | byron bay
# Processing Record 47 of Set 12 | russellville
# Processing Record 48 of Set 12 | surt
# Processing Record 49 of Set 12 | ippy
# Processing Record 0 of Set 13 | zhongshu
# Processing Record 1 of Set 13 | salvador
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 13 | shingu
# Processing Record 5 of Set 13 | vallenar
# Processing Record 6 of Set 13 | lyubeshiv
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Pevek  69.7008  170.3133    -32.20       100         100        0.94
# 1    Stralsund  54.3091   13.0818      3.34        58          40        3.58
# 2       Atuona  -9.8000 -139.0333     25.88        74          16        8.18
# 3  Henties Bay -22.1160   14.2845     21.52        72          66        5.12
# 4      Ushuaia -54.8000  -68.3000      9.81        62          40        6.69
#
#   Country        Date
# 0      RU  1675779131
# 1      DE  1675779131
# 2      PF  1675779132
# 3      NA  1675779132
# 4      AR  1675778581

# %%
city_data_df = city_data_df.rename(columns={"Lat":"Latitude","Lng":"Longitude"})

city_data_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0        Pevek   69.7008   170.3133    -32.20       100         100
# 1    Stralsund   54.3091    13.0818      3.34        58          40
# 2       Atuona   -9.8000  -139.0333     25.88        74          16
# 3  Henties Bay  -22.1160    14.2845     21.52        72          66
# 4      Ushuaia  -54.8000   -68.3000      9.81        62          40
#
#    Wind Speed Country        Date
# 0        0.94      RU  1675779131
# 1        3.58      DE  1675779131
# 2        8.18      PF  1675779132
# 3        5.12      NA  1675779132
# 4        6.69      AR  1675778581

# %%
# converting timestamp to date format and assigning value to chart title 

date = city_data_df["Date"]
date = pd.to_datetime(date, unit="s")
date_format = date.dt.date
city_data_df["Date"] = date_format

# %%
title_date = date_format[0].strftime("%Y-%m-%d")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              Pevek   69.7008   170.3133    -32.20       100         100
# 1          Stralsund   54.3091    13.0818      3.34        58          40
# 2             Atuona   -9.8000  -139.0333     25.88        74          16
# 3        Henties Bay  -22.1160    14.2845     21.52        72          66
# 4            Ushuaia  -54.8000   -68.3000      9.81        62          40
#
#          Wind Speed Country        Date
# City_ID
# 0              0.94      RU  2023-02-07
# 1              3.58      DE  2023-02-07
# 2              8.18      PF  2023-02-07
# 3              5.12     NaN  2023-02-07
# 4              6.69      AR  2023-02-07

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Latitude"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
plt.title(f"City Latitude vs Max Temperature - {title_date}")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Latitude"], city_data_df["Humidity"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.title(f"City Latitude vs Humidity - {title_date}")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Latitude"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.title(f"City Latitude vs Cloudiness - {title_date}")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Latitude"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
plt.title(f"City Latitude vs Wind Speed - {title_date}")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression(x_values, y_values, x_c=.1, y_c=.9):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, xy=(x_c, y_c), xycoords='axes fraction', fontsize=15,color="red")
    plt.xlabel (x_values.name)
    plt.ylabel (y_values.name)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df.loc[(city_data_df["Latitude"]>=0),:]

# Display sample data

northern_hemi_df.head()
# Out:
#                  City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Pevek   69.7008   170.3133    -32.20       100         100
# 1           Stralsund   54.3091    13.0818      3.34        58          40
# 5        Ballyshannon   54.5000    -8.1833      7.92        78          88
# 11        Verkhoyansk   67.5447   133.3850    -47.89       100          88
# 12              Vardø   70.3705    31.1107      2.99        81          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.94      RU  2023-02-07
# 1              3.58      DE  2023-02-07
# 5              2.48      IE  2023-02-07
# 11             0.70      RU  2023-02-07
# 12            10.80      NO  2023-02-07

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df = city_data_df.loc[(city_data_df["Latitude"]<0),:]

# Display sample data

southern_hemi_df.head()
# Out:
#                 City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             Atuona   -9.8000  -139.0333     25.88        74          16
# 3        Henties Bay  -22.1160    14.2845     21.52        72          66
# 4            Ushuaia  -54.8000   -68.3000      9.81        62          40
# 6         Bredasdorp  -34.5322    20.0403     23.77        60         100
# 7         Vila Velha  -20.3297   -40.2925     31.97        67          40
#
#          Wind Speed Country        Date
# City_ID
# 2              8.18      PF  2023-02-07
# 3              5.12     NaN  2023-02-07
# 4              6.69      AR  2023-02-07
# 6              5.68      ZA  2023-02-07
# 7              5.14      BR  2023-02-07

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df["Latitude"]
y_values = northern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.1, 0.1)
# Out:
# The r-squared is: 0.7294269914046874

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Latitude"]
y_values = southern_hemi_df["Max Temp"]

linear_regression(x_values, y_values, 0.4, 0.1)
# Out:
# The r-squared is: 0.3842446126967004

# %% [markdown]
# **Discussion about the linear relationship:**
#
# When analysing the relationship between latitude and max tempuratures for cities on the Northern Hemisphere, there is a strong negative correlation (r = 0.72): max temperature drops as the latitude increases.
#
# On the other hand, there is a week positive correlation between the same two variables on the Southern Hemisphere (r = 0.38). The reason for that may be the influence of other variables, such as the altitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Latitude"]
y_values = northern_hemi_df["Humidity"]

linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-squared is: 0.20810946508300499

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Latitude"]
y_values = southern_hemi_df["Humidity"]

linear_regression(x_values, y_values, 0.5, 0.1)
# Out:
# The r-squared is: 0.09432810573481276

# %% [markdown]
# **Discussion about the linear relationship:**
#
# When analysing the relationship between latitude and humidity for cities on the Northern Hemisphere, it is possible to notice a very week positive correlation (r = 0.20), while there is no correlation at all (r = 0.09) between the same variables for cities located on Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Latitude"]
y_values = northern_hemi_df["Cloudiness"]

linear_regression(x_values, y_values, 0.5, 0.3)
# Out:
# The r-squared is: 0.05924492983845572

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Latitude"]
y_values = southern_hemi_df["Cloudiness"]

linear_regression(x_values, y_values, 0.05, 0.8)
# Out:
# The r-squared is: 0.13103056846894195

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no correlation between Latitude and Cloudiness for cities on both hemispheres (r < 0.3).

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Latitude"]
y_values = northern_hemi_df["Wind Speed"]

linear_regression(x_values, y_values)
# Out:
# The r-squared is: 0.009859204960368224

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Latitude"]
y_values = southern_hemi_df["Wind Speed"]

linear_regression(x_values, y_values, 0.5, 0.8)
# Out:
# The r-squared is: 0.036125222162621456

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no correlation between Latitude and Wind Speed for cities on both hemispheres (r < 0.3).
